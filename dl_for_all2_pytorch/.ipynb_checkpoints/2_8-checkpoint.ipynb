# %%
# 복습 logestic regression
import torch
import torch.optim as optim

x_train = torch.FloatTensor([[1,2], [2,3], [3,1], [4,3], [5,3], [6,2]])
y_train = torch.FloatTensor([[0], [0], [0], [1], [1], [1]])

W = torch.zeros((2,1), requires_grad=True)
b = torch.zeros((1), requires_grad=True)

optimizer = optim.SGD([W,b], lr=1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1):
    hypothesis = torch.sigmoid(x_train.matmul(W) + b)
    cost = -(y_train * torch.log(hypothesis) + (1-y_train) * torch.log(1 - hypothesis)).mean()
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    print('Epoch: {:4d}/{} Cost : {:.6f}'.format(epoch, nb_epochs, cost.item()))
    prediction = hypothesis >= torch.FloatTensor([0.5])
    print(prediction)
# Out:
# Epoch:    0/1000 Cost : 0.693147
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Epoch:    1/1000 Cost : 1.009292
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Epoch:    2/1000 Cost : 1.410618
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [False]])
# Epoch:    3/1000 Cost : 2.546337
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Epoch:    4/1000 Cost : 0.621073
# tensor([[False],
#         [ True],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:    5/1000 Cost : 0.812270
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [ True]])
# Epoch:    6/1000 Cost : 1.592355
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Epoch:    7/1000 Cost : 0.442200
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:    8/1000 Cost : 0.460082
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:    9/1000 Cost : 0.495571
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   10/1000 Cost : 0.671355
# tensor([[False],
#         [ True],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   11/1000 Cost : 0.599569
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [False],
#         [ True]])
# Epoch:   12/1000 Cost : 0.955039
# tensor([[False],
#         [ True],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   13/1000 Cost : 0.495679
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   14/1000 Cost : 0.658035
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   15/1000 Cost : 0.500852
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   16/1000 Cost : 0.681982
# tensor([[False],
#         [ True],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   17/1000 Cost : 0.473170
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   18/1000 Cost : 0.621829
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   19/1000 Cost : 0.454665
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   20/1000 Cost : 0.590510
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   21/1000 Cost : 0.437992
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   22/1000 Cost : 0.565007
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   23/1000 Cost : 0.422848
# tensor([[False],
#         [False],
#         [ True],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   24/1000 Cost : 0.543383
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   25/1000 Cost : 0.408704
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   26/1000 Cost : 0.523732
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   27/1000 Cost : 0.395283
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   28/1000 Cost : 0.505132
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   29/1000 Cost : 0.382432
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   30/1000 Cost : 0.487127
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   31/1000 Cost : 0.370061
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   32/1000 Cost : 0.469493
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   33/1000 Cost : 0.358108
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   34/1000 Cost : 0.452114
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   35/1000 Cost : 0.346529
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   36/1000 Cost : 0.434934
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   37/1000 Cost : 0.335286
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   38/1000 Cost : 0.417926
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   39/1000 Cost : 0.324347
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   40/1000 Cost : 0.401081
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   41/1000 Cost : 0.313682
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   42/1000 Cost : 0.384398
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   43/1000 Cost : 0.303267
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   44/1000 Cost : 0.367884
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   45/1000 Cost : 0.293076
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   46/1000 Cost : 0.351558
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   47/1000 Cost : 0.283091
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   48/1000 Cost : 0.335443
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   49/1000 Cost : 0.273294
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   50/1000 Cost : 0.319570
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   51/1000 Cost : 0.263674
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   52/1000 Cost : 0.303984
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   53/1000 Cost : 0.254227
# tensor([[False],
#         [False],
#         [False],
#         [False],
#         [ True],
#         [ True]])
# Epoch:   54/1000 Cost : 0.288738
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   55/1000 Cost : 0.244953
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   56/1000 Cost : 0.273900
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   57/1000 Cost : 0.235864
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   58/1000 Cost : 0.259547
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   59/1000 Cost : 0.226980
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   60/1000 Cost : 0.245772
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   61/1000 Cost : 0.218332
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:   62/1000 Cost : 0.232677
# tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  970/1000 Cost : 0.020422
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  971/1000 Cost : 0.020402
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  972/1000 Cost : 0.020383
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  973/1000 Cost : 0.020363
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  974/1000 Cost : 0.020344
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  975/1000 Cost : 0.020325
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  976/1000 Cost : 0.020305
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  977/1000 Cost : 0.020286
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  978/1000 Cost : 0.020267
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  979/1000 Cost : 0.020247
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  980/1000 Cost : 0.020228
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  981/1000 Cost : 0.020209
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  982/1000 Cost : 0.020190
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  983/1000 Cost : 0.020171
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  984/1000 Cost : 0.020152
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  985/1000 Cost : 0.020133
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  986/1000 Cost : 0.020114
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  987/1000 Cost : 0.020095
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  988/1000 Cost : 0.020076
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  989/1000 Cost : 0.020057
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  990/1000 Cost : 0.020038
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  991/1000 Cost : 0.020020
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  992/1000 Cost : 0.020001
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  993/1000 Cost : 0.019982
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  994/1000 Cost : 0.019963
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  995/1000 Cost : 0.019945
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  996/1000 Cost : 0.019926
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  997/1000 Cost : 0.019908
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  998/1000 Cost : 0.019889
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch:  999/1000 Cost : 0.019871
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch: 1000/1000 Cost : 0.019852
# tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])

# %%
#복습 logestic regression by nn
import torch
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn

x_train = torch.FloatTensor([[1,2], [2,3], [3,1], [4,3], [5,3], [6,2]])
y_train = torch.FloatTensor([[0], [0], [0], [1], [1], [1]])

model = nn.Sequential(nn.Linear(2,1), nn.Sigmoid())

optimizer = optim.SGD(model.parameters(), lr=1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1) : 
    hypothesis = model(x_train)
    cost = F.binary_cross_entropy(hypothesis, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%10==0:
        prediction = hypothesis >= torch.FloatTensor([0.5])
        
        print('Epoch : {:4d}/{} prediction : {}'.format(epoch, nb_epochs, prediction))
# Out:
# Epoch :    0/1000 prediction : tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])
# Epoch :   10/1000 prediction : tensor([[False],
#         [ True],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   20/1000 prediction : tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   30/1000 prediction : tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   40/1000 prediction : tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   50/1000 prediction : tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   60/1000 prediction : tensor([[False],
#         [False],
#         [ True],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   70/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   80/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :   90/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  100/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  110/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  120/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  130/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  140/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  150/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  160/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  170/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  180/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  190/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  200/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  210/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  220/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  230/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  240/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  250/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  260/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  270/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  280/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  290/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  300/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  310/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  320/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  330/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  340/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  350/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  360/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  370/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  380/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  390/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  400/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  410/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  420/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  430/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  440/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  450/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  460/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  470/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  480/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  490/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  500/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  510/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  520/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  530/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  540/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  550/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  560/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  570/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  580/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  590/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  600/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  610/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  620/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  630/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  640/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  650/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  660/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  670/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  680/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  690/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  700/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  710/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  720/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  730/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  740/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  750/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  760/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  770/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  780/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  790/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  800/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  810/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  820/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  830/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  840/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  850/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  860/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  870/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  880/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  890/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  900/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  910/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  920/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  930/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  940/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  950/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  960/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  970/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  980/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch :  990/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])
# Epoch : 1000/1000 prediction : tensor([[False],
#         [False],
#         [False],
#         [ True],
#         [ True],
#         [ True]])

# %%
# 클래스로 구현하기
# model = nn.Sequential(nn.Linear(2,1), nn.Sigmoid())
class BinaryClassifier(nn.Module):
    def __init__(self) :
        super().__init__()
        self.linear = nn.Linear(2,1)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x) :
        return self.sigmoid(self.linear(x))

# %%
#Softmax regression 
import torch
import torch.optim as optim
import torch.nn.functional as F

torch.manual_seed(1)

x_train = [[1,2,1,1],
          [2,1,3,2],
          [3,1,3,4],
          [4,1,5,5],
          [1,7,5,5],
          [1,2,5,6],
          [1,6,6,6],
          [1,7,7,7]]
y_train = [2,2,2,1,1,1,0,0]
x_train = torch.FloatTensor(x_train)
y_train = torch.LongTensor(y_train)

y_one_hot = torch.zeros(8,3)
y_one_hot.scatter_(1, y_train.unsqueeze(1), 1)

W = torch.zeros((4,3), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

optimizer = optim.SGD([W,b], lr=0.1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1):
    hypothesis = F.softmax(x_train.matmul(W) + b, dim=1)
    cost = (y_one_hot * -torch.log(hypothesis)).sum(dim=1).mean()
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    if epoch%10==0:
        print('Epoch: {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch:    0/1000 Cost: 1.098612
# Epoch:   10/1000 Cost: 1.069288
# Epoch:   20/1000 Cost: 0.960612
# Epoch:   30/1000 Cost: 0.901738
# Epoch:   40/1000 Cost: 0.863738
# Epoch:   50/1000 Cost: 0.836334
# Epoch:   60/1000 Cost: 0.815246
# Epoch:   70/1000 Cost: 0.798249
# Epoch:   80/1000 Cost: 0.784040
# Epoch:   90/1000 Cost: 0.771814
# Epoch:  100/1000 Cost: 0.761050
# Epoch:  110/1000 Cost: 0.751401
# Epoch:  120/1000 Cost: 0.742627
# Epoch:  130/1000 Cost: 0.734554
# Epoch:  140/1000 Cost: 0.727057
# Epoch:  150/1000 Cost: 0.720039
# Epoch:  160/1000 Cost: 0.713425
# Epoch:  170/1000 Cost: 0.707157
# Epoch:  180/1000 Cost: 0.701187
# Epoch:  190/1000 Cost: 0.695476
# Epoch:  200/1000 Cost: 0.689991
# Epoch:  210/1000 Cost: 0.684706
# Epoch:  220/1000 Cost: 0.679597
# Epoch:  230/1000 Cost: 0.674647
# Epoch:  240/1000 Cost: 0.669836
# Epoch:  250/1000 Cost: 0.665151
# Epoch:  260/1000 Cost: 0.660580
# Epoch:  270/1000 Cost: 0.656111
# Epoch:  280/1000 Cost: 0.651735
# Epoch:  290/1000 Cost: 0.647444
# Epoch:  300/1000 Cost: 0.643229
# Epoch:  310/1000 Cost: 0.639084
# Epoch:  320/1000 Cost: 0.635003
# Epoch:  330/1000 Cost: 0.630981
# Epoch:  340/1000 Cost: 0.627013
# Epoch:  350/1000 Cost: 0.623094
# Epoch:  360/1000 Cost: 0.619221
# Epoch:  370/1000 Cost: 0.615390
# Epoch:  380/1000 Cost: 0.611597
# Epoch:  390/1000 Cost: 0.607841
# Epoch:  400/1000 Cost: 0.604117
# Epoch:  410/1000 Cost: 0.600425
# Epoch:  420/1000 Cost: 0.596761
# Epoch:  430/1000 Cost: 0.593123
# Epoch:  440/1000 Cost: 0.589510
# Epoch:  450/1000 Cost: 0.585919
# Epoch:  460/1000 Cost: 0.582350
# Epoch:  470/1000 Cost: 0.578800
# Epoch:  480/1000 Cost: 0.575268
# Epoch:  490/1000 Cost: 0.571754
# Epoch:  500/1000 Cost: 0.568255
# Epoch:  510/1000 Cost: 0.564771
# Epoch:  520/1000 Cost: 0.561301
# Epoch:  530/1000 Cost: 0.557843
# Epoch:  540/1000 Cost: 0.554397
# Epoch:  550/1000 Cost: 0.550961
# Epoch:  560/1000 Cost: 0.547536
# Epoch:  570/1000 Cost: 0.544120
# Epoch:  580/1000 Cost: 0.540713
# Epoch:  590/1000 Cost: 0.537314
# Epoch:  600/1000 Cost: 0.533922
# Epoch:  610/1000 Cost: 0.530536
# Epoch:  620/1000 Cost: 0.527158
# Epoch:  630/1000 Cost: 0.523784
# Epoch:  640/1000 Cost: 0.520416
# Epoch:  650/1000 Cost: 0.517053
# Epoch:  660/1000 Cost: 0.513693
# Epoch:  670/1000 Cost: 0.510338
# Epoch:  680/1000 Cost: 0.506986
# Epoch:  690/1000 Cost: 0.503637
# Epoch:  700/1000 Cost: 0.500291
# Epoch:  710/1000 Cost: 0.496947
# Epoch:  720/1000 Cost: 0.493605
# Epoch:  730/1000 Cost: 0.490265
# Epoch:  740/1000 Cost: 0.486926
# Epoch:  750/1000 Cost: 0.483588
# Epoch:  760/1000 Cost: 0.480252
# Epoch:  770/1000 Cost: 0.476916
# Epoch:  780/1000 Cost: 0.473580
# Epoch:  790/1000 Cost: 0.470244
# Epoch:  800/1000 Cost: 0.466908
# Epoch:  810/1000 Cost: 0.463572
# Epoch:  820/1000 Cost: 0.460235
# Epoch:  830/1000 Cost: 0.456898
# Epoch:  840/1000 Cost: 0.453560
# Epoch:  850/1000 Cost: 0.450221
# Epoch:  860/1000 Cost: 0.446881
# Epoch:  870/1000 Cost: 0.443539
# Epoch:  880/1000 Cost: 0.440196
# Epoch:  890/1000 Cost: 0.436853
# Epoch:  900/1000 Cost: 0.433507
# Epoch:  910/1000 Cost: 0.430159
# Epoch:  920/1000 Cost: 0.426810
# Epoch:  930/1000 Cost: 0.423460
# Epoch:  940/1000 Cost: 0.420108
# Epoch:  950/1000 Cost: 0.416754
# Epoch:  960/1000 Cost: 0.413398
# Epoch:  970/1000 Cost: 0.410041
# Epoch:  980/1000 Cost: 0.406683
# Epoch:  990/1000 Cost: 0.403323
# Epoch: 1000/1000 Cost: 0.399962

# %%
#Softmax regression by nn
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim

x_train = [[1,2,1,1],
          [2,1,3,2],
          [3,1,3,4],
          [4,1,5,5],
          [1,7,5,5],
          [1,2,5,6],
          [1,6,6,6],
          [1,7,7,7]]
y_train = [2,2,2,1,1,1,0,0]
x_train = torch.FloatTensor(x_train)
y_train = torch.LongTensor(y_train)

model = nn.Linear(4,3)
optimizer = optim.SGD(model.parameters(), lr=0.1)

nb_epochs = 1000
for epoch in range(nb_epochs + 1):
    prediction = model(x_train)
    cost = F.cross_entropy(prediction, y_train) # 주의 : F.cross_entropy 에는 one-hot, softmax 모두 포함되어있음
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if epoch%100==0:
        print('Epoch: {:4d}/{} Cost: {:.6f}'.format(epoch, nb_epochs, cost.item()))
# Out:
# Epoch:    0/1000 Cost: 1.366217
# Epoch:  100/1000 Cost: 0.722726
# Epoch:  200/1000 Cost: 0.637564
# Epoch:  300/1000 Cost: 0.578576
# Epoch:  400/1000 Cost: 0.527363
# Epoch:  500/1000 Cost: 0.479315
# Epoch:  600/1000 Cost: 0.432700
# Epoch:  700/1000 Cost: 0.386693
# Epoch:  800/1000 Cost: 0.340930
# Epoch:  900/1000 Cost: 0.295757
# Epoch: 1000/1000 Cost: 0.255350

# %%
# MNIST
#torch.nn.functional.cross_entropy() 대신 torch.nn.CrossEntropyLoss() 사용
import torch
import torch.nn as nn
import torch.optim as optim
import random
from torch.utils.data import DataLoader
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
print("다음 기기로 학습합니다 :", device)

random.seed(777)
torch.manual_seed(777)
if device=='cuda':
    torch.cuda.manual_seed(777)
    
training_epochs = 15
batch_size = 100

mnist_train = dsets.MNIST(root='MNIST_data/',
                         train = True,
                         transform = transforms.ToTensor(),
                         download = True)
mnist_test = dsets.MNIST(root='MNIST_data/',
                        train = False,
                        transform = transforms.ToTensor(),
                        download = True)
data_loader = DataLoader(dataset=mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)

linear = nn.Linear(784,10).to(device)
optimizer = optim.SGD(linear.parameters(), lr=0.1)
criterion = nn.CrossEntropyLoss().to(device)

for epoch in range(training_epochs):
    avg_cost = 0
    total_batch = len(data_loader)
    
    for X,Y in data_loader:
        X = X.view(-1, 28*28).to(device)
        Y = Y.to(device)
        
        hypothesis = linear(X)
        cost = criterion(hypothesis, Y)
        
        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        
        avg_cost += cost / total_batch
    print('Epoch:{:4d}/{} Cost:{:.6f}'.format(epoch+1, training_epochs, avg_cost))
# Out:
# 다음 기기로 학습합니다 : cpu
# Epoch:   1/15 Cost:0.535151
# Epoch:   2/15 Cost:0.359578
# Epoch:   3/15 Cost:0.331264
# Epoch:   4/15 Cost:0.316405
# Epoch:   5/15 Cost:0.307107
# Epoch:   6/15 Cost:0.300457
# Epoch:   7/15 Cost:0.294933
# Epoch:   8/15 Cost:0.290956
# Epoch:   9/15 Cost:0.287074
# Epoch:  10/15 Cost:0.284516
# Epoch:  11/15 Cost:0.281914
# Epoch:  12/15 Cost:0.279527
# Epoch:  13/15 Cost:0.277637
# Epoch:  14/15 Cost:0.275875
# Epoch:  15/15 Cost:0.274423

# %%
# 테스트 데이터를 사용하여 모델을 테스트한다.
with torch.no_grad(): # torch.no_grad()를 하면 gradient 계산을 수행하지 않는다.
    X_test = mnist_test.test_data.view(-1, 28 * 28).float().to(device)
    Y_test = mnist_test.test_labels.to(device)

    prediction = linear(X_test)
    correct_prediction = torch.argmax(prediction, 1) == Y_test
    accuracy = correct_prediction.float().mean()
    print('Accuracy:', accuracy.item())

    # MNIST 테스트 데이터에서 무작위로 하나를 뽑아서 예측을 해본다
    r = random.randint(0, len(mnist_test) - 1)
    X_single_data = mnist_test.test_data[r:r + 1].view(-1, 28 * 28).float().to(device)
    Y_single_data = mnist_test.test_labels[r:r + 1].to(device)

    print('Label: ', Y_single_data.item())
    single_prediction = linear(X_single_data)
    print('Prediction: ', torch.argmax(single_prediction, 1).item())

    plt.imshow(mnist_test.test_data[r:r + 1].view(28, 28), cmap='Greys', interpolation='nearest')
    plt.show()
# Out:
# C:\anaconda3\envs\tensorflow\lib\site-packages\torchvision\datasets\mnist.py:67: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\anaconda3\envs\tensorflow\lib\site-packages\torchvision\datasets\mnist.py:57: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# Accuracy: 0.8883000016212463
# Label:  8
# Prediction:  3
