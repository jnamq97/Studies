# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/study/'
# Out:
# /gdrive/MyDrive/study/VDSR

# %%
# !git remote rm origin

# %%
# !git pull
# Out:
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=<remote>/<branch> main

# %%
# !git pull https://github.com/jnamq97/Graduation_paper_studies.git main --allow-unrelated-histories
# Out:
# From https://github.com/jnamq97/Graduation_paper_studies
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !echo "#lib" >> README.md
# !git init
# !git config --global user.email "namkyo0724@gmail.com"
# !git config --global user.name "jnamq97"
# !git add README.md
# !git add For_github_commit.ipynb
# !git add DL.ipynb
# !git add numpy.ipynb
# !git add pandas.ipynb
# !git add opencv.ipynb
# !git commit -m "first commit"
# !git branch -M master
# !git remote add origin https://jnamq97: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@github.com/jnamq97/Studies.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/study/VDSR/.git/
# [main dd72ac1] first commit
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite For_github_commit.ipynb (78%)
# Counting objects: 117, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (111/111), done.
# Writing objects: 100% (117/117), 38.55 MiB | 5.23 MiB/s, done.
# Total 117 (delta 23), reused 0 (delta 0)
# remote: Resolving deltas: 100% (23/23), done.
# To https://github.com/jnamq97/Graduation_paper_studies.git
#    1c14bc8..dd72ac1  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add .
# !git commit -m "setup"
# !git push
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
# Out:
# ^C
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	For_github_commit.ipynb
# 	Results/
# 	VDSR_SE_test/
# 	VDSR_test/
# 	data/
# 	source_code/
# 	weights/
#
# nothing added to commit but untracked files present
# Everything up-to-date
