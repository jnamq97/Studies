# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd '/gdrive/MyDrive/study/'
# Out:
# /gdrive/MyDrive/study

# %%
# !git remote rm origin

# %%
# !git pull
# Out:
# warning: no common commits
# remote: Enumerating objects: 1044, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 1044 (delta 6), reused 22 (delta 6), pack-reused 1022
# Receiving objects: 100% (1044/1044), 261.04 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# From https://github.com/jnamq97/Studies
#  * [new branch]      master     -> origin/master
# There is no tracking information for the current branch.
# Please specify which branch you want to merge with.
# See git-pull(1) for details.
#
#     git pull <remote> <branch>
#
# If you wish to set tracking information for this branch you can do so with:
#
#     git branch --set-upstream-to=origin/<branch> master

# %%
# !git pull https://github.com/jnamq97/Studies.git master --allow-unrelated-histories
# Out:
# From https://github.com/jnamq97/Studies
#  * branch            master     -> FETCH_HEAD

# %%
# !echo "#lib" >> README.md
# !git init
# !git config --global user.email "namkyo0724@gmail.com"
# !git config --global user.name "jnamq97"
# !git add README.md
# !git add For_github_commit.ipynb
# !git add DL.ipynb
# !git add numpy.ipynb
# !git add pandas.ipynb
# !git add opencv.ipynb
# !git commit -m "first commit"
# !git branch -M master
# !git remote add origin https://jnamq97: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@github.com/jnamq97/Studies.git
# !git push -u origin master
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/study/.git/
# [master 80f2947] first commit
#  1 file changed, 1 insertion(+)
# To https://github.com/jnamq97/Studies.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://jnamq97: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@github.com/jnamq97/Studies.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git add .
# !git commit -m "setup"
# !git push
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
# Out:
# ^C
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	For_github_commit.ipynb
# 	Results/
# 	VDSR_SE_test/
# 	VDSR_test/
# 	data/
# 	source_code/
# 	weights/
#
# nothing added to commit but untracked files present
# Everything up-to-date
